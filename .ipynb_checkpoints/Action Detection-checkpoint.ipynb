# %% [markdown]
# ### 1. Import and Install Dependencies

# %% [markdown]
# ! pip install tensorflow==2.18.0 opencv-python mediapipe scikit-learn matplotlib

# %%
import cv2 
import matplotlib.pyplot as plt
import numpy as np
import os
import time
import mediapipe as mp

# %% [markdown]
# ### 2. Keypoints using MP Holistic

# %%
mp_holistic = mp.solutions.holistic # Holistic Model
mp_drawing = mp.solutions.drawing_utils # Drawing Utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # Convert color BGR to RGB
    image.flags.writeable = False                   # Image is no longer writeable
    results = model.process(image)                         # Make prediction
    image.flags.writeable = True                   # Image is writeable now
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # Convert color RGB to BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS)   # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS)       # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS)  # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS,
                                mp_drawing.DrawingSpec(color=(80, 110, 10), thickness=1, circle_radius=1),
                                mp_drawing.DrawingSpec(color=(80, 256, 124), thickness=1, circle_radius=1)
                             )
    
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                                mp_drawing.DrawingSpec(color=(80, 22, 10), thickness=1, circle_radius=1),
                                mp_drawing.DrawingSpec(color=(80, 44, 124), thickness=1, circle_radius=1)
                             )
    
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                                mp_drawing.DrawingSpec(color=(121, 22, 76), thickness=1, circle_radius=1),
                                mp_drawing.DrawingSpec(color=(121, 44, 250), thickness=1, circle_radius=1)
                             )
    
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                                mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=1, circle_radius=1),
                                    mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=1, circle_radius=1)
                             )

# %% [markdown]
# ### 3. Extract Keypoints

# %%
print(len(results.pose_landmarks.landmark)) # 33
print(len(results.face_landmarks.landmark)) # 468
print(len(results.left_hand_landmarks.landmark)) # 21
print(len(results.right_hand_landmarks.landmark)) # 21

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468 * 3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21 * 3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21 * 3)
    
    return np.concatenate([pose, face, lh, rh])

# %%
print("Over all features:", 33 * 4 + 468 * 3 + 21 * 3 + 21 * 3)
# Out:
# Over all features: 1662

# %%
len(extract_keypoints(results))
# Out:
# 1662

# %%
cap = cv2.VideoCapture(0)
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read Feeds
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)

        # print(results)
        draw_styled_landmarks(image, results)
        # draw_landmarks(image, results)
        
        
        # Show to screen
        cv2.imshow("Footage", image)

        # Break Gracefully
        if cv2.waitKey(10) & 0xFF == ord("q"):
            break
    cap.release()
    cv2.destroyAllWindows()

# %% [markdown]
# ### 4. Setup Folder for collection

# %%
# Path for exported data, numpy arrays 
DATA_PATH = os.path.join("MP_Data")

# Actions that we try to detect 
actions = np.array(["hello", "thanks", "iloveyou"])

# Thirty Videos worth of data
no_sequences = 30

# Videos are going to 30 frames in length 
sequence_length = 30

# %%
# hello
## 0
## 1
## 2
## ...
## 29

# thanks

# I love you

# %%
for action in actions:
    for sequence in range(no_sequences):
        try:
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %% [markdown]
# ### 5. Collect Keypoint Values for Training and Testing

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:

    # New Loop
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):


                # Read Feed
                ret, frame = cap.read()

                # Make Detections
                image, results = mediapipe_detection(frame, holistic)

                # Draw Landmarks
                draw_styled_landmarks(image, results)

                if frame_num == 0:
                    cv2.putText(image, "STARTING COLLECTION", (120, 200),
                                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15, 12),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow("OpenCV Feed", image)
                    cv2.waitKey(2000) # wait for 2 second
                else:
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                    
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break Gracefully
                if cv2.waitKey(10) & 0xFF == ord("q"):
                    break
    cap.release()
    cv2.destroyAllWindows()

# %% [markdown]
# ### 6. Preprocess Data and Create Labels and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label: num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'hello': 0, 'thanks': 1, 'iloveyou': 2}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)

        sequences.append(window)
        labels.append(label_map[action])

# %%
X = np.array(sequences)
y = np.array(labels)

# %%
X.shape
# Out:
# (90, 30, 1662)

# %%
y.shape
# Out:
# (90,)

# %%
y = to_categorical(labels).astype(int)

# %%
y[:2]
# Out:
# array([[1, 0, 0],
#        [1, 0, 0]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, random_state=42, stratify=y)

# %%
y_test.shape
# Out:
# (5, 3)

# %% [markdown]
# ### 7. Build and Train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join("logs")
tb_calllback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30, 1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))
# Out:
# C:\Users\ADMIN\miniconda3\envs\myenv\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_crossentropy'])

# %%
model.fit(X_train, y_train, epochs=800, callbacks=[tb_calllback])
# Out:
# Epoch 1/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - categorical_crossentropy: 1.0787 - loss: 1.0787
# Epoch 2/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - categorical_crossentropy: 1.0537 - loss: 1.0537
# Epoch 3/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 232ms/step - categorical_crossentropy: 1.0045 - loss: 1.0045
# Epoch 4/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 204ms/step - categorical_crossentropy: 0.9272 - loss: 0.9272
# Epoch 5/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - categorical_crossentropy: 0.8150 - loss: 0.8150
# Epoch 6/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - categorical_crossentropy: 4.0742 - loss: 4.0742
# Epoch 7/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - categorical_crossentropy: 1.0180 - loss: 1.0180
# Epoch 8/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - categorical_crossentropy: 1.1229 - loss: 1.1229
# Epoch 9/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - categorical_crossentropy: 1.0971 - loss: 1.0971
# Epoch 10/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - categorical_crossentropy: 1.1034 - loss: 1.1034
# Epoch 11/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - categorical_crossentropy: 1.1083 - loss: 1.1083
# Epoch 12/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - categorical_crossentropy: 1.1004 - loss: 1.1004
# Epoch 13/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - categorical_crossentropy: 1.1075 - loss: 1.1075
# Epoch 14/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - categorical_crossentropy: 1.1057 - loss: 1.1057
# Epoch 15/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 176ms/step - categorical_crossentropy: 1.1058 - loss: 1.1058
# Epoch 16/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - categorical_crossentropy: 1.1028 - loss: 1.1028
# Epoch 17/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - categorical_crossentropy: 1.0995 - loss: 1.0995
# Epoch 18/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - categorical_crossentropy: 1.1026 - loss: 1.1026
# Epoch 19/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - categorical_crossentropy: 1.1022 - loss: 1.1022
# Epoch 20/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - categorical_crossentropy: 1.1050 - loss: 1.1050
# Epoch 21/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - categorical_crossentropy: 1.1067 - loss: 1.1067
# Epoch 22/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 210ms/step - categorical_crossentropy: 1.1053 - loss: 1.1053
# Epoch 23/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - categorical_crossentropy: 1.0972 - loss: 1.0972
# Epoch 24/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - categorical_crossentropy: 1.0982 - loss: 1.0982
# Epoch 25/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step - categorical_crossentropy: 1.1025 - loss: 1.1025
# Epoch 26/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step - categorical_crossentropy: 1.0988 - loss: 1.0988
# Epoch 27/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - categorical_crossentropy: 1.0967 - loss: 1.0967
# Epoch 28/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - categorical_crossentropy: 1.1001 - loss: 1.1001
# Epoch 29/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 157ms/step - categorical_crossentropy: 1.0988 - loss: 1.0988
# Epoch 30/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - categorical_crossentropy: 1.1017 - loss: 1.1017
# Epoch 31/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - categorical_crossentropy: 1.1013 - loss: 1.1013
# Epoch 32/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - categorical_crossentropy: 1.1017 - loss: 1.1017
# Epoch 33/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - categorical_crossentropy: 1.0978 - loss: 1.0978
# Epoch 34/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 187ms/step - categorical_crossentropy: 1.1013 - loss: 1.1013
# Epoch 35/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - categorical_crossentropy: 1.0995 - loss: 1.0995
# Epoch 36/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step - categorical_crossentropy: 1.1012 - loss: 1.1012
# Epoch 37/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - categorical_crossentropy: 1.1006 - loss: 1.1006
# Epoch 38/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - categorical_crossentropy: 1.0987 - loss: 1.0987
# Epoch 39/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 259ms/step - categorical_crossentropy: 1.0986 - loss: 1.0986
# Epoch 40/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - categorical_crossentropy: 1.0993 - loss: 1.0993
# Epoch 41/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 156ms/step - categorical_crossentropy: 1.1004 - loss: 1.1004
# Epoch 42/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - categorical_crossentropy: 1.0995 - loss: 1.0995
# Epoch 43/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 156ms/step - categorical_crossentropy: 1.0991 - loss: 1.0991
# Epoch 44/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 157ms/step - categorical_crossentropy: 1.0987 - loss: 1.0987
# Epoch 45/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - categorical_crossentropy: 1.0971 - loss: 1.0971
# Epoch 46/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 157ms/step - categorical_crossentropy: 1.0992 - loss: 1.0992
# Epoch 47/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 157ms/step - categorical_crossentropy: 1.0990 - loss: 1.0990
# Epoch 48/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 156ms/step - categorical_crossentropy: 1.0993 - loss: 1.0993
# Epoch 49/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step - categorical_crossentropy: 1.0988 - loss: 1.0988
# Epoch 50/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - categorical_crossentropy: 1.0990 - loss: 1.0990
# Epoch 51/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - categorical_crossentropy: 1.0992 - loss: 1.0992
# Epoch 52/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 179ms/step - categorical_crossentropy: 1.0998 - loss: 1.0998
# Epoch 53/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - categorical_crossentropy: 1.0992 - loss: 1.0992
# Epoch 54/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - categorical_crossentropy: 1.0985 - loss: 1.0985
# Epoch 55/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - categorical_crossentropy: 1.0986 - loss: 1.0986
# Epoch 56/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - categorical_crossentropy: 1.0983 - loss: 1.0983
# Epoch 57/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - categorical_crossentropy: 1.0979 - loss: 1.0979
# Epoch 58/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - categorical_crossentropy: 1.0981 - loss: 1.0981
# Epoch 59/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - categorical_crossentropy: 1.0981 - loss: 1.0981
# Epoch 60/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - categorical_crossentropy: 1.0982 - loss: 1.0982
# Epoch 61/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - categorical_crossentropy: 1.0978 - loss: 1.0978
# Epoch 62/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - categorical_crossentropy: 1.0978 - loss: 1.0978
# Epoch 63/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - categorical_crossentropy: 1.0977 - loss: 1.0977
# Epoch 64/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - categorical_crossentropy: 1.0964 - loss: 1.0964
# Epoch 65/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - categorical_crossentropy: 1.0964 - loss: 1.0964
# Epoch 66/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - categorical_crossentropy: 1.0934 - loss: 1.0934
# Epoch 67/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - categorical_crossentropy: 1.0902 - loss: 1.0902
# Epoch 68/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - categorical_crossentropy: 1.0782 - loss: 1.0782
# Epoch 69/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - categorical_crossentropy: 1.3013 - loss: 1.3013
# Epoch 70/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 222ms/step - categorical_crossentropy: 1.0986 - loss: 1.0986
# Epoch 71/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - categorical_crossentropy: 1.0959 - loss: 1.0959
# Epoch 72/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - categorical_crossentropy: 1.0962 - loss: 1.0962
# Epoch 73/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - categorical_crossentropy: 1.1035 - loss: 1.1035
# Epoch 74/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - categorical_crossentropy: 1.0988 - loss: 1.0988
# Epoch 75/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - categorical_crossentropy: 1.1004 - loss: 1.1004
# Epoch 76/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - categorical_crossentropy: 1.0979 - loss: 1.0979
# Epoch 77/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - categorical_crossentropy: 1.1018 - loss: 1.1018
# Epoch 78/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - categorical_crossentropy: 1.0998 - loss: 1.0998
# Epoch 79/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - categorical_crossentropy: 1.0984 - loss: 1.0984
# Epoch 80/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - categorical_crossentropy: 1.0999 - loss: 1.0999
# Epoch 81/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 204ms/step - categorical_crossentropy: 1.1029 - loss: 1.1029
# Epoch 82/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - categorical_crossentropy: 1.0988 - loss: 1.0988
# Epoch 83/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - categorical_crossentropy: 1.0995 - loss: 1.0995
# Epoch 84/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - categorical_crossentropy: 1.1010 - loss: 1.1010
# Epoch 85/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - categorical_crossentropy: 1.0980 - loss: 1.0980
# Epoch 86/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - categorical_crossentropy: 1.1003 - loss: 1.1003
# Epoch 87/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - categorical_crossentropy: 1.0992 - loss: 1.0992
# Epoch 88/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - categorical_crossentropy: 1.0992 - loss: 1.0992
# Epoch 89/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - categorical_crossentropy: 1.0998 - loss: 1.0998
# Epoch 90/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step - categorical_crossentropy: 1.0992 - loss: 1.0992
# Epoch 91/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - categorical_crossentropy: 1.0993 - loss: 1.0993
# Epoch 92/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 175ms/step - categorical_crossentropy: 1.0985 - loss: 1.0985
# Epoch 93/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 228ms/step - categorical_crossentropy: 1.0990 - loss: 1.0990
# Epoch 94/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - categorical_crossentropy: 1.0988 - loss: 1.0988
# Epoch 95/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - categorical_crossentropy: 1.0975 - loss: 1.0975
# Epoch 96/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - categorical_crossentropy: 1.0987 - loss: 1.0987
# Epoch 97/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - categorical_crossentropy: 1.0992 - loss: 1.0992
# Epoch 98/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - categorical_crossentropy: 1.0985 - loss: 1.0985
# Epoch 99/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step - categorical_crossentropy: 1.0982 - loss: 1.0982
# Epoch 100/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - categorical_crossentropy: 1.0990 - loss: 1.0990
# Epoch 101/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 136ms/step - categorical_crossentropy: 1.0988 - loss: 1.0988
# Epoch 102/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 157ms/step - categorical_crossentropy: 1.0981 - loss: 1.0981
# Epoch 103/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step - categorical_crossentropy: 1.0979 - loss: 1.0979
# Epoch 104/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - categorical_crossentropy: 1.0990 - loss: 1.0990
# Epoch 105/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - categorical_crossentropy: 1.0988 - loss: 1.0988
# Epoch 106/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - categorical_crossentropy: 1.0988 - loss: 1.0988
# Epoch 107/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - categorical_crossentropy: 1.0984 - loss: 1.0984
# Epoch 108/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - categorical_crossentropy: 1.0985 - loss: 1.0985
# Epoch 109/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - categorical_crossentropy: 1.0981 - loss: 1.0981
# Epoch 110/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - categorical_crossentropy: 1.0988 - loss: 1.0988
# Epoch 111/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 230ms/step - categorical_crossentropy: 1.0987 - loss: 1.0987
# Epoch 112/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 185ms/step - categorical_crossentropy: 1.0982 - loss: 1.0982
# Epoch 113/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 140ms/step - categorical_crossentropy: 1.0992 - loss: 1.0992
# Epoch 114/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - categorical_crossentropy: 1.0987 - loss: 1.0987
# Epoch 115/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - categorical_crossentropy: 1.0989 - loss: 1.0989
# Epoch 116/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - categorical_crossentropy: 1.0982 - loss: 1.0982
# Epoch 117/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - categorical_crossentropy: 1.0986 - loss: 1.0986
# Epoch 118/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - categorical_crossentropy: 1.0988 - loss: 1.0988
# Epoch 119/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - categorical_crossentropy: 1.0984 - loss: 1.0984
# Epoch 120/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - categorical_crossentropy: 1.0988 - loss: 1.0988
# Epoch 121/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - categorical_crossentropy: 1.0989 - loss: 1.0989
# Epoch 122/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - categorical_crossentropy: 1.0987 - loss: 1.0987
# Epoch 123/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - categorical_crossentropy: 1.0992 - loss: 1.0992
# Epoch 124/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - categorical_crossentropy: 1.0978 - loss: 1.0978
# Epoch 125/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - categorical_crossentropy: 1.0978 - loss: 1.0978
# Epoch 126/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - categorical_crossentropy: 1.0984 - loss: 1.0984
# Epoch 127/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - categorical_crossentropy: 1.0988 - loss: 1.0988
# Epoch 128/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - categorical_crossentropy: 1.0976 - loss: 1.0976
# Epoch 129/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - categorical_crossentropy: 1.0986 - loss: 1.0986
# Epoch 130/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 137ms/step - categorical_crossentropy: 1.0890 - loss: 1.0890
# Epoch 131/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - categorical_crossentropy: 2.4207 - loss: 2.4207
# Epoch 132/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - categorical_crossentropy: 1.0972 - loss: 1.0972
# Epoch 133/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - categorical_crossentropy: 1.0987 - loss: 1.0987
# Epoch 134/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - categorical_crossentropy: 1.0991 - loss: 1.0991
# Epoch 135/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - categorical_crossentropy: 1.0997 - loss: 1.0997
# Epoch 136/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 209ms/step - categorical_crossentropy: 1.0975 - loss: 1.0975
# Epoch 137/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - categorical_crossentropy: 1.1026 - loss: 1.1026
# Epoch 138/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - categorical_crossentropy: 1.1001 - loss: 1.1001
# Epoch 139/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - categorical_crossentropy: 1.1000 - loss: 1.1000
# Epoch 140/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - categorical_crossentropy: 1.0996 - loss: 1.0996
# Epoch 141/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - categorical_crossentropy: 1.0962 - loss: 1.0962
# Epoch 142/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - categorical_crossentropy: 1.1002 - loss: 1.1002
# Epoch 143/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - categorical_crossentropy: 1.0989 - loss: 1.0989
# Epoch 144/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - categorical_crossentropy: 1.0970 - loss: 1.0970
# Epoch 145/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - categorical_crossentropy: 1.0980 - loss: 1.0980
# Epoch 146/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - categorical_crossentropy: 1.0973 - loss: 1.0973
# Epoch 147/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - categorical_crossentropy: 1.0978 - loss: 1.0978
# Epoch 148/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - categorical_crossentropy: 1.0974 - loss: 1.0974
# Epoch 149/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - categorical_crossentropy: 1.0971 - loss: 1.0971
# Epoch 150/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 177ms/step - categorical_crossentropy: 1.0970 - loss: 1.0970
# Epoch 151/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step - categorical_crossentropy: 1.0926 - loss: 1.0926
# Epoch 152/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - categorical_crossentropy: 1.0945 - loss: 1.0945
# Epoch 153/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - categorical_crossentropy: 1.0870 - loss: 1.0870
# Epoch 154/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - categorical_crossentropy: 1.0943 - loss: 1.0943
# Epoch 155/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - categorical_crossentropy: 1.0995 - loss: 1.0995
# Epoch 156/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - categorical_crossentropy: 1.0993 - loss: 1.0993
# Epoch 157/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - categorical_crossentropy: 1.1005 - loss: 1.1005
# Epoch 158/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 221ms/step - categorical_crossentropy: 1.0980 - loss: 1.0980
# Epoch 159/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step - categorical_crossentropy: 1.1006 - loss: 1.1006
# Epoch 160/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - categorical_crossentropy: 1.0991 - loss: 1.0991
# Epoch 161/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - categorical_crossentropy: 1.0980 - loss: 1.0980
# Epoch 162/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step - categorical_crossentropy: 1.0991 - loss: 1.0991
# Epoch 163/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - categorical_crossentropy: 1.1012 - loss: 1.1012
# Epoch 164/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - categorical_crossentropy: 1.0997 - loss: 1.0997
# Epoch 165/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - categorical_crossentropy: 1.1011 - loss: 1.1011
# Epoch 166/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - categorical_crossentropy: 1.0975 - loss: 1.0975
# Epoch 167/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - categorical_crossentropy: 1.0971 - loss: 1.0971
# Epoch 168/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - categorical_crossentropy: 1.0988 - loss: 1.0988
# Epoch 169/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 187ms/step - categorical_crossentropy: 1.0995 - loss: 1.0995
# Epoch 170/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - categorical_crossentropy: 1.1005 - loss: 1.1005
# Epoch 171/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - categorical_crossentropy: 1.1015 - loss: 1.1015
# Epoch 172/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - categorical_crossentropy: 1.1012 - loss: 1.1012
# Epoch 173/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - categorical_crossentropy: 1.0990 - loss: 1.0990
# Epoch 174/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - categorical_crossentropy: 1.0989 - loss: 1.0989
# Epoch 175/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - categorical_crossentropy: 1.1003 - loss: 1.1003
# Epoch 176/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step - categorical_crossentropy: 1.0973 - loss: 1.0973
# Epoch 177/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - categorical_crossentropy: 1.0990 - loss: 1.0990
# Epoch 178/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - categorical_crossentropy: 1.0993 - loss: 1.0993
# Epoch 179/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - categorical_crossentropy: 1.0987 - loss: 1.0987
# Epoch 180/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - categorical_crossentropy: 1.0998 - loss: 1.0998
# Epoch 181/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - categorical_crossentropy: 1.0977 - loss: 1.0977
# Epoch 182/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - categorical_crossentropy: 1.0980 - loss: 1.0980
# Epoch 183/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step - categorical_crossentropy: 1.0999 - loss: 1.0999
# Epoch 184/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - categorical_crossentropy: 1.0989 - loss: 1.0989
# Epoch 185/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - categorical_crossentropy: 1.0989 - loss: 1.0989
# Epoch 186/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - categorical_crossentropy: 1.0973 - loss: 1.0973
# Epoch 187/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - categorical_crossentropy: 1.0998 - loss: 1.0998
# Epoch 188/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - categorical_crossentropy: 1.0962 - loss: 1.0962
# Epoch 189/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 208ms/step - categorical_crossentropy: 1.0971 - loss: 1.0971
# Epoch 190/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - categorical_crossentropy: 1.0966 - loss: 1.0966
# Epoch 191/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - categorical_crossentropy: 1.0965 - loss: 1.0965
# Epoch 192/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - categorical_crossentropy: 1.1003 - loss: 1.1003
# Epoch 193/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - categorical_crossentropy: 1.0962 - loss: 1.0962
# Epoch 194/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - categorical_crossentropy: 1.0976 - loss: 1.0976
# Epoch 195/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 181ms/step - categorical_crossentropy: 1.0978 - loss: 1.0978
# Epoch 196/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 137ms/step - categorical_crossentropy: 1.0988 - loss: 1.0988
# Epoch 197/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - categorical_crossentropy: 1.0977 - loss: 1.0977
# Epoch 198/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - categorical_crossentropy: 1.0980 - loss: 1.0980
# Epoch 199/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - categorical_crossentropy: 1.0990 - loss: 1.0990
# Epoch 200/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - categorical_crossentropy: 1.0976 - loss: 1.0976
# Epoch 201/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - categorical_crossentropy: 1.0963 - loss: 1.0963
# Epoch 202/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - categorical_crossentropy: 1.0977 - loss: 1.0977
# Epoch 203/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - categorical_crossentropy: 1.0994 - loss: 1.0994
# Epoch 204/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - categorical_crossentropy: 1.0975 - loss: 1.0975
# Epoch 205/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - categorical_crossentropy: 1.0986 - loss: 1.0986
# Epoch 206/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - categorical_crossentropy: 1.0965 - loss: 1.0965
# Epoch 207/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - categorical_crossentropy: 1.0996 - loss: 1.0996
# Epoch 208/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - categorical_crossentropy: 1.0979 - loss: 1.0979
# Epoch 209/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - categorical_crossentropy: 1.0984 - loss: 1.0984
# Epoch 210/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - categorical_crossentropy: 1.0990 - loss: 1.0990
# Epoch 211/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - categorical_crossentropy: 1.0987 - loss: 1.0987
# Epoch 212/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 241ms/step - categorical_crossentropy: 1.0972 - loss: 1.0972
# Epoch 213/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step - categorical_crossentropy: 1.0992 - loss: 1.0992
# Epoch 214/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - categorical_crossentropy: 1.0982 - loss: 1.0982
# Epoch 215/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - categorical_crossentropy: 1.0986 - loss: 1.0986
# Epoch 216/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - categorical_crossentropy: 1.0992 - loss: 1.0992
# Epoch 217/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - categorical_crossentropy: 1.0991 - loss: 1.0991
# Epoch 218/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - categorical_crossentropy: 1.0993 - loss: 1.0993
# Epoch 219/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - categorical_crossentropy: 1.0984 - loss: 1.0984
# Epoch 220/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - categorical_crossentropy: 1.1000 - loss: 1.1000
# Epoch 221/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - categorical_crossentropy: 1.0967 - loss: 1.0967
# Epoch 222/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - categorical_crossentropy: 1.0982 - loss: 1.0982
# Epoch 223/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - categorical_crossentropy: 1.0981 - loss: 1.0981
# Epoch 224/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - categorical_crossentropy: 1.0992 - loss: 1.0992
# Epoch 225/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - categorical_crossentropy: 1.0987 - loss: 1.0987
# Epoch 226/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - categorical_crossentropy: 1.0980 - loss: 1.0980
# Epoch 227/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - categorical_crossentropy: 1.0981 - loss: 1.0981
# Epoch 228/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 222ms/step - categorical_crossentropy: 1.0984 - loss: 1.0984
# Epoch 229/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - categorical_crossentropy: 1.0989 - loss: 1.0989
# Epoch 230/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 229ms/step - categorical_crossentropy: 1.0982 - loss: 1.0982
# Epoch 231/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - categorical_crossentropy: 1.0980 - loss: 1.0980
# Epoch 232/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - categorical_crossentropy: 1.1000 - loss: 1.1000
# Epoch 233/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - categorical_crossentropy: 1.0980 - loss: 1.0980
# Epoch 234/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - categorical_crossentropy: 1.0980 - loss: 1.0980
# Epoch 235/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - categorical_crossentropy: 1.0986 - loss: 1.0986
# Epoch 236/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - categorical_crossentropy: 1.0984 - loss: 1.0984
# Epoch 237/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - categorical_crossentropy: 1.0992 - loss: 1.0992
# Epoch 238/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - categorical_crossentropy: 1.0971 - loss: 1.0971
# Epoch 239/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - categorical_crossentropy: 1.0986 - loss: 1.0986
# Epoch 240/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - categorical_crossentropy: 1.0995 - loss: 1.0995
# Epoch 241/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - categorical_crossentropy: 1.0979 - loss: 1.0979
# Epoch 242/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - categorical_crossentropy: 1.0989 - loss: 1.0989
# Epoch 243/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - categorical_crossentropy: 1.0987 - loss: 1.0987
# Epoch 244/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - categorical_crossentropy: 1.0981 - loss: 1.0981
# Epoch 245/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - categorical_crossentropy: 1.0996 - loss: 1.0996
# Epoch 246/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 224ms/step - categorical_crossentropy: 1.0987 - loss: 1.0987
# Epoch 247/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step - categorical_crossentropy: 1.0988 - loss: 1.0988
# Epoch 248/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - categorical_crossentropy: 1.0980 - loss: 1.0980
# Epoch 249/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - categorical_crossentropy: 1.0988 - loss: 1.0988
# Epoch 250/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - categorical_crossentropy: 1.0976 - loss: 1.0976
# Epoch 251/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - categorical_crossentropy: 1.0978 - loss: 1.0978
# Epoch 252/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - categorical_crossentropy: 1.0977 - loss: 1.0977
# Epoch 253/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - categorical_crossentropy: 1.0990 - loss: 1.0990
# Epoch 254/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - categorical_crossentropy: 1.0984 - loss: 1.0984
# Epoch 255/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - categorical_crossentropy: 1.0981 - loss: 1.0981
# Epoch 256/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - categorical_crossentropy: 1.0978 - loss: 1.0978
# Epoch 257/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - categorical_crossentropy: 1.0993 - loss: 1.0993
# Epoch 258/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - categorical_crossentropy: 1.0978 - loss: 1.0978
# Epoch 259/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - categorical_crossentropy: 1.0985 - loss: 1.0985
# Epoch 260/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - categorical_crossentropy: 1.0979 - loss: 1.0979
# Epoch 261/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - categorical_crossentropy: 1.0977 - loss: 1.0977
# Epoch 262/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - categorical_crossentropy: 1.0986 - loss: 1.0986
# Epoch 263/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - categorical_crossentropy: 1.0986 - loss: 1.0986
# Epoch 264/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 137ms/step - categorical_crossentropy: 1.0975 - loss: 1.0975
# Epoch 265/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - categorical_crossentropy: 1.0988 - loss: 1.0988
# Epoch 266/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step - categorical_crossentropy: 1.0987 - loss: 1.0987
# Epoch 267/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - categorical_crossentropy: 1.0980 - loss: 1.0980
# Epoch 268/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - categorical_crossentropy: 1.0994 - loss: 1.0994
# Epoch 269/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - categorical_crossentropy: 1.0983 - loss: 1.0983
# Epoch 270/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - categorical_crossentropy: 1.0977 - loss: 1.0977
# Epoch 271/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - categorical_crossentropy: 1.0985 - loss: 1.0985
# Epoch 272/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - categorical_crossentropy: 1.0970 - loss: 1.0970
# Epoch 273/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 136ms/step - categorical_crossentropy: 1.0989 - loss: 1.0989
# Epoch 274/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - categorical_crossentropy: 1.0997 - loss: 1.0997
# Epoch 275/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - categorical_crossentropy: 1.0977 - loss: 1.0977
# Epoch 276/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - categorical_crossentropy: 1.0986 - loss: 1.0986
# Epoch 277/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - categorical_crossentropy: 1.0973 - loss: 1.0973
# Epoch 278/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - categorical_crossentropy: 1.0975 - loss: 1.0975
# Epoch 279/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - categorical_crossentropy: 1.0985 - loss: 1.0985
# Epoch 280/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - categorical_crossentropy: 1.0987 - loss: 1.0987
# Epoch 281/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - categorical_crossentropy: 1.0986 - loss: 1.0986
# Epoch 282/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - categorical_crossentropy: 1.0983 - loss: 1.0983
# Epoch 283/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - categorical_crossentropy: 1.0975 - loss: 1.0975
# Epoch 284/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - categorical_crossentropy: 1.0983 - loss: 1.0983
# Epoch 285/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - categorical_crossentropy: 1.0983 - loss: 1.0983
# Epoch 286/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 135ms/step - categorical_crossentropy: 1.0987 - loss: 1.0987
# Epoch 287/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - categorical_crossentropy: 1.0991 - loss: 1.0991
# Epoch 288/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - categorical_crossentropy: 1.0926 - loss: 1.0926
# Epoch 289/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - categorical_crossentropy: 29.8582 - loss: 29.8582
# Epoch 290/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - categorical_crossentropy: 0.9551 - loss: 0.9551
# Epoch 291/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 156ms/step - categorical_crossentropy: 1.1039 - loss: 1.1039
# Epoch 292/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - categorical_crossentropy: 1.0946 - loss: 1.0946
# Epoch 293/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - categorical_crossentropy: 1.0944 - loss: 1.0944
# Epoch 294/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 202ms/step - categorical_crossentropy: 1.0869 - loss: 1.0869
# Epoch 295/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - categorical_crossentropy: 1.0725 - loss: 1.0725
# Epoch 296/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - categorical_crossentropy: 1.0786 - loss: 1.0786
# Epoch 297/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - categorical_crossentropy: 1.1171 - loss: 1.1171
# Epoch 298/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - categorical_crossentropy: 1.0869 - loss: 1.0869
# Epoch 299/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - categorical_crossentropy: 1.0995 - loss: 1.0995
# Epoch 300/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - categorical_crossentropy: 1.0981 - loss: 1.0981
# Epoch 301/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - categorical_crossentropy: 1.0978 - loss: 1.0978
# Epoch 302/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - categorical_crossentropy: 1.0947 - loss: 1.0947
# Epoch 303/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - categorical_crossentropy: 1.0946 - loss: 1.0946
# Epoch 304/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 230ms/step - categorical_crossentropy: 1.0934 - loss: 1.0934
# Epoch 305/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - categorical_crossentropy: 1.0887 - loss: 1.0887
# Epoch 306/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - categorical_crossentropy: 1.0868 - loss: 1.0868
# Epoch 307/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - categorical_crossentropy: 1.0786 - loss: 1.0786
# Epoch 308/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - categorical_crossentropy: 1.0610 - loss: 1.0610
# Epoch 309/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 138ms/step - categorical_crossentropy: 1.0329 - loss: 1.0329
# Epoch 310/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - categorical_crossentropy: 1.0128 - loss: 1.0128
# Epoch 311/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - categorical_crossentropy: 0.9540 - loss: 0.9540
# Epoch 312/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - categorical_crossentropy: 1.0206 - loss: 1.0206
# Epoch 313/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - categorical_crossentropy: 0.9382 - loss: 0.9382
# Epoch 314/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - categorical_crossentropy: 0.9586 - loss: 0.9586
# Epoch 315/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - categorical_crossentropy: 1.0123 - loss: 1.0123
# Epoch 316/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - categorical_crossentropy: 0.8510 - loss: 0.8510
# Epoch 317/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step - categorical_crossentropy: 0.8077 - loss: 0.8077
# Epoch 318/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - categorical_crossentropy: 0.7472 - loss: 0.7472
# Epoch 319/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - categorical_crossentropy: 0.6897 - loss: 0.6897
# Epoch 320/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step - categorical_crossentropy: 0.8139 - loss: 0.8139
# Epoch 321/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - categorical_crossentropy: 0.7188 - loss: 0.7188
# Epoch 322/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - categorical_crossentropy: 0.7661 - loss: 0.7661
# Epoch 323/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - categorical_crossentropy: 0.7379 - loss: 0.7379
# Epoch 324/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - categorical_crossentropy: 1.1773 - loss: 1.1773
# Epoch 325/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - categorical_crossentropy: 1.0093 - loss: 1.0093
# Epoch 326/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - categorical_crossentropy: 0.7027 - loss: 0.7027
# Epoch 327/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - categorical_crossentropy: 0.7773 - loss: 0.7773
# Epoch 328/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - categorical_crossentropy: 0.7542 - loss: 0.7542
# Epoch 329/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - categorical_crossentropy: 0.6845 - loss: 0.6845
# Epoch 330/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - categorical_crossentropy: 0.6833 - loss: 0.6833
# Epoch 331/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - categorical_crossentropy: 0.6451 - loss: 0.6451
# Epoch 332/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - categorical_crossentropy: 0.6029 - loss: 0.6029
# Epoch 333/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - categorical_crossentropy: 0.5542 - loss: 0.5542
# Epoch 334/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - categorical_crossentropy: 0.5611 - loss: 0.5611
# Epoch 335/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - categorical_crossentropy: 0.4899 - loss: 0.4899
# Epoch 336/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 195ms/step - categorical_crossentropy: 0.4525 - loss: 0.4525
# Epoch 337/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - categorical_crossentropy: 0.4446 - loss: 0.4446
# Epoch 338/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - categorical_crossentropy: 0.8026 - loss: 0.8026
# Epoch 339/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - categorical_crossentropy: 0.8644 - loss: 0.8644
# Epoch 340/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - categorical_crossentropy: 0.6247 - loss: 0.6247
# Epoch 341/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step - categorical_crossentropy: 0.5466 - loss: 0.5466
# Epoch 342/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - categorical_crossentropy: 0.4894 - loss: 0.4894
# Epoch 343/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - categorical_crossentropy: 0.5296 - loss: 0.5296
# Epoch 344/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 208ms/step - categorical_crossentropy: 0.4759 - loss: 0.4759
# Epoch 345/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - categorical_crossentropy: 0.4353 - loss: 0.4353
# Epoch 346/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - categorical_crossentropy: 0.4535 - loss: 0.4535
# Epoch 347/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - categorical_crossentropy: 0.4486 - loss: 0.4486
# Epoch 348/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step - categorical_crossentropy: 0.4512 - loss: 0.4512
# Epoch 349/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step - categorical_crossentropy: 0.4664 - loss: 0.4664
# Epoch 350/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 157ms/step - categorical_crossentropy: 0.4184 - loss: 0.4184
# Epoch 351/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - categorical_crossentropy: 0.3768 - loss: 0.3768
# Epoch 352/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - categorical_crossentropy: 0.4325 - loss: 0.4325
# Epoch 353/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - categorical_crossentropy: 0.4849 - loss: 0.4849
# Epoch 354/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 189ms/step - categorical_crossentropy: 0.5148 - loss: 0.5148
# Epoch 355/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 498ms/step - categorical_crossentropy: 0.3898 - loss: 0.3898
# Epoch 356/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 136ms/step - categorical_crossentropy: 0.3777 - loss: 0.3777
# Epoch 357/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - categorical_crossentropy: 0.3841 - loss: 0.3841
# Epoch 358/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - categorical_crossentropy: 0.3488 - loss: 0.3488
# Epoch 359/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - categorical_crossentropy: 0.3789 - loss: 0.3789
# Epoch 360/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - categorical_crossentropy: 0.3543 - loss: 0.3543
# Epoch 361/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - categorical_crossentropy: 0.3245 - loss: 0.3245
# Epoch 362/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - categorical_crossentropy: 0.3573 - loss: 0.3573
# Epoch 363/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step - categorical_crossentropy: 0.3379 - loss: 0.3379
# Epoch 364/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - categorical_crossentropy: 0.3108 - loss: 0.3108
# Epoch 365/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - categorical_crossentropy: 0.3003 - loss: 0.3003
# Epoch 366/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - categorical_crossentropy: 0.2973 - loss: 0.2973
# Epoch 367/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - categorical_crossentropy: 0.4426 - loss: 0.4426
# Epoch 368/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 137ms/step - categorical_crossentropy: 0.4907 - loss: 0.4907
# Epoch 369/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - categorical_crossentropy: 0.4727 - loss: 0.4727
# Epoch 370/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - categorical_crossentropy: 0.4962 - loss: 0.4962
# Epoch 371/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 268ms/step - categorical_crossentropy: 0.3216 - loss: 0.3216
# Epoch 372/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step - categorical_crossentropy: 0.3018 - loss: 0.3018
# Epoch 373/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - categorical_crossentropy: 0.2787 - loss: 0.2787
# Epoch 374/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - categorical_crossentropy: 0.3089 - loss: 0.3089
# Epoch 375/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - categorical_crossentropy: 0.3032 - loss: 0.3032
# Epoch 376/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - categorical_crossentropy: 0.3222 - loss: 0.3222
# Epoch 377/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - categorical_crossentropy: 0.3692 - loss: 0.3692
# Epoch 378/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - categorical_crossentropy: 0.3092 - loss: 0.3092
# Epoch 379/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - categorical_crossentropy: 0.2557 - loss: 0.2557
# Epoch 380/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 198ms/step - categorical_crossentropy: 0.2977 - loss: 0.2977
# Epoch 381/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 191ms/step - categorical_crossentropy: 0.3551 - loss: 0.3551
# Epoch 382/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - categorical_crossentropy: 0.3430 - loss: 0.3430
# Epoch 383/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 205ms/step - categorical_crossentropy: 0.2891 - loss: 0.2891
# Epoch 384/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 213ms/step - categorical_crossentropy: 0.2995 - loss: 0.2995
# Epoch 385/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 240ms/step - categorical_crossentropy: 0.2538 - loss: 0.2538
# Epoch 386/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 178ms/step - categorical_crossentropy: 0.2611 - loss: 0.2611
# Epoch 387/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step - categorical_crossentropy: 0.3112 - loss: 0.3112
# Epoch 388/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 140ms/step - categorical_crossentropy: 0.2498 - loss: 0.2498
# Epoch 389/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - categorical_crossentropy: 0.2226 - loss: 0.2226
# Epoch 390/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 198ms/step - categorical_crossentropy: 0.2972 - loss: 0.2972
# Epoch 391/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - categorical_crossentropy: 0.2029 - loss: 0.2029
# Epoch 392/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - categorical_crossentropy: 0.1924 - loss: 0.1924
# Epoch 393/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - categorical_crossentropy: 0.1969 - loss: 0.1969
# Epoch 394/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - categorical_crossentropy: 0.8741 - loss: 0.8741
# Epoch 395/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - categorical_crossentropy: 0.7684 - loss: 0.7684
# Epoch 396/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - categorical_crossentropy: 0.5693 - loss: 0.5693
# Epoch 397/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - categorical_crossentropy: 0.2449 - loss: 0.2449
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 model.fit(X_train, y_train, epochs=800, callbacks=[tb_calllback])
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:369, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     367 callbacks.on_train_batch_begin(step)
#     368 logs = self.train_function(iterator)
# --> 369 callbacks.on_train_batch_end(step, logs)
#     370 if self.stop_training:
#     371     break
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\keras\src\callbacks\callback_list.py:172, in CallbackList.on_train_batch_end(self, batch, logs)
#     170     self._async_dispatch(self._on_train_batch_end, batch, logs)
#     171 else:
# --> 172     self._on_train_batch_end(batch, logs)
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\keras\src\callbacks\callback_list.py:194, in CallbackList._on_train_batch_end(self, batch, logs)
#     192 logs = python_utils.pythonify_logs(logs)
#     193 for callback in self.callbacks:
# --> 194     callback.on_train_batch_end(batch, logs=logs)
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\keras\src\callbacks\progbar_logger.py:58, in ProgbarLogger.on_train_batch_end(self, batch, logs)
#      57 def on_train_batch_end(self, batch, logs=None):
# ---> 58     self._update_progbar(batch, logs)
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\keras\src\callbacks\progbar_logger.py:95, in ProgbarLogger._update_progbar(self, batch, logs)
#      92 self.seen = batch + 1  # One-indexed.
#      94 if self.verbose == 1:
# ---> 95     self.progbar.update(self.seen, list(logs.items()), finalize=False)
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\keras\src\utils\progbar.py:182, in Progbar.update(self, current, values, finalize)
#     179 if finalize:
#     180     message += "\n"
# --> 182 io_utils.print_msg(message, line_break=False)
#     183 self._prev_total_width = total_width
#     184 message = ""
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\keras\src\utils\io_utils.py:107, in print_msg(message, line_break)
#     105         message = message_bytes.decode(sys.stdout.encoding)
#     106         sys.stdout.write(message)
# --> 107     sys.stdout.flush()
#     108 else:
#     109     logging.info(message)
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\ipykernel\iostream.py:609, in OutStream.flush(self)
#     607     self.pub_thread.schedule(evt.set)
#     608     # and give a timeout to avoid
# --> 609     if not evt.wait(self.flush_timeout):
#     610         # write directly to __stderr__ instead of warning because
#     611         # if this is happening sys.stderr may be the problem.
#     612         print("IOStream.flush timed out", file=sys.__stderr__)
#     613 else:
#
# File ~\miniconda3\envs\myenv\Lib\threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File ~\miniconda3\envs\myenv\Lib\threading.py:359, in Condition.wait(self, timeout)
#     357 else:
#     358     if timeout > 0:
# --> 359         gotit = waiter.acquire(True, timeout)
#     360     else:
#     361         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 30, 64)              │         442,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 30, 128)             │          98,816 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 64)                  │          49,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 3)                   │              99 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,790,027 (6.83 MB)
#  Trainable params: 596,675 (2.28 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,193,352 (4.55 MB)

# %% [markdown]
# ### 8. Model Prediction

# %%
res = model.predict(X_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step

# %%
for i in range(5):
    print("Predicted:", actions[np.argmax(res[i])])
    print("Actual:", actions[np.argmax(y_test[i])], "\n")
# Out:
# Predicted: hello
# Actual: iloveyou
#
# Predicted: hello
# Actual: thanks
#
# Predicted: hello
# Actual: thanks
#
# Predicted: hello
# Actual: hello
#
# Predicted: hello
# Actual: hello

# %%
len(res)
# Out:
# 5

# %% [markdown]
# ### 9. Save Model

# %%
model.save("action.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Load model
# del model
model.load_weights('action.h5')

# %% [markdown]
# ### 10. Evaluation using Confusion Matrix and Accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = np.argmax(model.predict(X_train), axis=1).tolist()
ytrue = np.argmax(y_train, axis=1).tolist()
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[57,  0],
#         [16, 12]],
#
#        [[54,  3],
#         [ 0, 28]],
#
#        [[42, 14],
#         [ 1, 28]]], dtype=int64)

# %% [markdown]
# ### 11. Test in Real Time

# %%
# New Detection variables 
sequence = []
sentence = []
threshold = 0.6

cap = cv2.VideoCapture(0)
# Set mediapipe model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        # print(results)

        # Draw Landmarks
        draw_styled_landmarks( image, results )

        # 2. Prediction logic 
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]

        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])

            # Threshold
            print(res[np.argmax(res)])

        
        # 3. Visualize Logic

            if res[np.argmax(res)] > threshold:
                if len(sentence) > 0:
                    if actions[np.argmax(res)] != sentence[-1]:
                        sentence.append(actions[np.argmax(res)])
                else:
                    sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5:
                sentence = sentence[-5:]
        cv2.rectangle(image, (0, 0), (640, 40), (247, 117, 16), -1)
        cv2.putText(image, " ".join(sentence), (3, 30),
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)


        # Show to screen
        cv2.imshow("OpenCV Feed", image)

        # Break gracefully
        if cv2.waitKey(10) & 0xff == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# thanks
# 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# thanks
# 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# thanks
# 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# thanks
# 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# thanks
# 0.99999976
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# thanks
# 0.9998627
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# thanks
# 0.7736003
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# iloveyou
# 0.99559647
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# iloveyou
# 0.9994948
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# iloveyou
# 0.9998672
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# iloveyou
# 0.99995697
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# iloveyou
# 0.99998355
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# iloveyou
# 0.99999344
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# iloveyou
# 0.9999975
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# iloveyou
# 0.99999905
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# iloveyou
# 0.99999964
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# iloveyou
# 0.99999976
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# iloveyou
# 0.9999995
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# iloveyou
# 0.9999968
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# iloveyou
# 0.99997103
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# iloveyou
# 0.9992754
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# iloveyou
# 0.99968266
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# iloveyou
# 0.8960671
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# iloveyou
# 0.652412
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# iloveyou
# 0.69965786
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# iloveyou
# 0.7148993
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# iloveyou
# 0.731157
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# iloveyou
# 0.7424859
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# iloveyou
# 0.7369313
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# iloveyou
# 0.7429896
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# iloveyou
# 0.76986504
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# iloveyou
# 0.7044729
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# iloveyou
# 0.72702837
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# iloveyou
# 0.74308264
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# iloveyou
# 0.6886109
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# iloveyou
# 0.6958789
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# iloveyou
# 0.69339055
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# iloveyou
# 0.67501724
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# iloveyou
# 0.6621037
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# iloveyou
# 0.6417929
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# iloveyou
# 0.61466885
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# iloveyou
# 0.57915795
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# iloveyou
# 0.53919685
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# hello
# 0.5001482
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# hello
# 0.5238006
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# hello
# 0.5659849
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# hello
# 0.6040748
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# hello
# 0.635782
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# hello
# 0.66680026
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# hello
# 0.67994344
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# hello
# 0.697263
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# hello
# 0.71513623
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# hello
# 0.7322812
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# hello
# 0.7067904
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# hello
# 0.7185104
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# hello
# 0.71619815
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# hello
# 0.71152914
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# hello
# 0.70394415
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# hello
# 0.6926602
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# hello
# 0.6893543
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# hello
# 0.6789544
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# hello
# 0.672857
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# hello
# 0.66894394
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# hello
# 0.6609199
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# hello
# 0.66126627
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# hello
# 0.65939814
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# hello
# 0.6559005
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# hello
# 0.658684
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# hello
# 0.6595643
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# hello
# 0.664378
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# hello
# 0.6659475
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# hello
# 0.67061836
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# hello
# 0.6707478
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# hello
# 0.66800994
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# hello
# 0.6595992
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# hello
# 0.652731
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# hello
# 0.64803106
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# hello
# 0.6453771
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# hello
# 0.64292747
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# hello
# 0.6433937
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# hello
# 0.64527434
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# hello
# 0.6479438
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# hello
# 0.6510048
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# hello
# 0.6493142
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# hello
# 0.6474297
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# hello
# 0.6306567
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# hello
# 0.6077033
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# hello
# 0.5900427
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# hello
# 0.5751037
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# hello
# 0.5599346
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# hello
# 0.5262181
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# iloveyou
# 0.503702
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# iloveyou
# 0.55316544
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# iloveyou
# 0.62970483
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# iloveyou
# 0.74310577
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# iloveyou
# 0.8566885
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
